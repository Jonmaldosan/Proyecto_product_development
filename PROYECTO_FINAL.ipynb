# %% [markdown]
# # CARGA DE LAS LIBRERIAS

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import pandas_profiling as pp
from ydata_profiling import ProfileReport
# Out:
# /var/folders/4j/dcxs948x2_z98dj_6scrl76m0000gn/T/ipykernel_25264/247029105.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %% [markdown]
# # CARGA DEL DATASET

# %%
data_car = pd.read_csv('/Users/jonmaldosan/Documents/PAPD 2023/4to. Ciclo/Product_Developmet/PROYECTO_FINAL/proyecto_final/data/CarPrice_Assignment.csv')
data_car.head()
# Out:
#    car_ID                   CarName fueltype aspiration doornumber  \
# 0       1        alfa-romero giulia      gas        std        two
# 1       2       alfa-romero stelvio      gas        std        two
# 2       3  alfa-romero Quadrifoglio      gas        std        two
# 3       4               audi 100 ls      gas        std       four
# 4       5                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation cylindernumber  enginesize  \
# 0  convertible        rwd          front           four         130
# 1  convertible        rwd          front           four         130
# 2    hatchback        rwd          front            six         152
# 3        sedan        fwd          front           four         109
# 4        sedan        4wd          front           five         136
#
#   fuelsystem  horsepower    price
# 0       mpfi         111  13495.0
# 1       mpfi         111  16500.0
# 2       mpfi         154  16500.0
# ...

# %% [markdown]
# # ANALISIS EXPLORATORIO Y PROFILING DE LOS DATOS

# %%
ProfileReport(data_car, title="Pandas DataFrame")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-19 07:45:44.952645&quot;&gt;&lt;title&gt;Pandas DataFrame&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### DESCRIPCION DE LOS WARNINGS GENERADOS EN EL EDA

# %% [markdown]
# ##### Correlaciones Altas:
# * Las variables aspiration, carbody, cylindernumber, doornumber, drivewheel, enginesize, enginetype, fuelsystem, fueltype, horsepower, price y muestran alta correlación con otras variables.
#
# ##### Desbalance en Variables Categóricas:
# * Las variables categóricas como fueltype, enginelocation, y cylindernumber están altamente desbalanceadas.
#
# ##### Distribución Uniforme y Valores Unicos:
# * car_ID también tiene valores únicos y esta uniformemente distribuida, lo cual es esperado ya que se trata de un identificador único para cada entrada.

# %% [markdown]
# # SETUP E INGENIERIA DE CARACTERISTICAS

# %%
from pycaret.regression import *

# %%
exploracion = setup(
    data_car, 
    target='price', 
    remove_multicollinearity=True,
    ignore_features=['car_ID'],
    feature_selection=True, 
    normalize=True, 
    transformation=True, 
    transformation_method='yeo-johnson')
# Out:
# <style type="text/css">
# #T_5e62b_row11_col1, #T_5e62b_row17_col1, #T_5e62b_row19_col1, #T_5e62b_row21_col1, #T_5e62b_row23_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e62b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e62b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5e62b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e62b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e62b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e62b_row0_col1" class="data row0 col1" >6129</td>
#     </tr>
#     <tr>
#       <th id="T_5e62b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e62b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e62b_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### Definiciones y justificaciones:
#
# | Correlativo | Título                                   | Descripción                                             |
# |-------------|------------------------------------------|---------------------------------------------------------|
# | 1           | Session id                               | Identificador de la sesión de PyCaret.                  |
# | 2           | Target                                   | La variable objetivo que estás tratando de predecir (`price` en este caso). |
# | 3           | Target type                              | Tipo de tarea de modelado, en este caso, es un problema de regresión. |
# | 4           | Original data shape                      | Forma del conjunto de datos original antes de cualquier transformación. |
# | 5           | Transformed data shape                   | Forma del conjunto de datos después de aplicar transformaciones. |
# | 6           | Transformed train set shape               | Forma del conjunto de entrenamiento después de transformaciones. |
# | 7           | Transformed test set shape                | Forma del conjunto de prueba después de transformaciones. |
# | 8           | Ignore features                          | Número de características ignoradas durante el setup.    |
# | 9           | Ordinal features                         | Número de características ordinales en el conjunto de datos. |
# | 10          | Numeric features                         | Número de características numéricas en el conjunto de datos. |
# | 11          | Categorical features                     | Número de características categóricas en el conjunto de datos. |
# | 12          | Preprocess                               | Si se aplicaron procesamientos al conjunto de datos (True/False). |
# | 13          | Imputation type                          | Tipo de imputación para valores faltantes en el conjunto de datos. |
# | 14          | Numeric imputation                       | Método de imputación para valores faltantes en variables numéricas. |
# | 15          | Categorical imputation                   | Método de imputación para valores faltantes en variables categóricas. |
# | 16          | Maximum one-hot encoding                  | Número máximo de codificaciones one-hot permitidas.      |
# | 17          | Encoding method                          | Método de codificación utilizado.                        |
# | 18          | Remove multicollinearity                 | Si se eliminaron características altamente correlacionadas. |
# | 19          | Multicollinearity threshold              | Umbral para la eliminación de multicolinealidad.        |
# | 20          | Transformation                           | Si se aplicaron transformaciones a las variables.       |
# | 21          | Transformation method                    | Método específico de transformación utilizado.           |
# | 22          | Normalize                                | Si se normalizaron las variables.                        |
# | 23          | Normalize method                         | Método de normalización utilizado.                      |
# | 24          | Feature selection                        | Si se realizó la selección de características.           |
# | 25          | Feature selection method                 | Método específico de selección de características.      |
# | 26          | Feature selection estimator              | Estimador utilizado para la selección de características. |
# | 27          | Number of features selected              | Número de características seleccionadas.               |
# | 28          | Fold Generator                           | Generador de pliegues utilizado para validación cruzada. |
# | 29          | Fold Number                              | Número de pliegues en la validación cruzada.            |
# | 30          | CPU Jobs                                 | Número de trabajos de CPU utilizados durante el procesamiento. |
# | 31          | Use GPU                                  | Si se utiliza GPU para acelerar el procesamiento.       |
# | 32          | Log Experiment                           | Si se registran los experimentos.                        |
# | 33          | Experiment Name                          | Nombre del experimento.                                  |
# | 34          | USI                                      | Identificador único del experimento.                     |

# %% [markdown]
# # DATA TRAIN Y DATA TEST

# %%
# Division de los datos para entrenamiento y prueba
train_data = get_config('X_train')
test_data = get_config('X_test')

# %% [markdown]
# # ENTRENAMIENTO Y SELECCION AUTOMATICA DE MODELOS

# %%
# Comparar modelos y almacenar los resultados
select_models = compare_models(sort='RMSE')
# Out:
# <style type="text/css">
# #T_762b9 th {
#   text-align: left;
# }
# ...

# %%
modelo_1 = finalize_model(select_models)

# %%
save_model(modelo_1, model_name='/Users/jonmaldosan/Documents/PAPD 2023/4to. Ciclo/Product_Developmet/PROYECTO_FINAL/proyecto_final/models/modelo_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['enginesize', 'horsepower'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['CarName', 'fueltype',
#                                               'aspiration', 'doornumber',
#                                               'carbody', 'drivewheel',
#                                               'enginelocation', 'cylindernumber',
#                                               'fuelsystem'],
#                                      transformer=SimpleImputer(stra...
#                                      transformer=RemoveMulticollinearity(threshold=0.9))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
# ...
